# %% [markdown]
# <a href="https://colab.research.google.com/github/havaledar/ECON3740_F24/blob/main/ECON3740_F24_Lab_1_b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Donwload the Excel file

# %% [markdown]
# ![Screenshot from 2024-09-11 17-35-10.png](data:image/png;base64,...)

# %% [markdown]
# # Import pandas

# %%
import pandas as pd

# %% [markdown]
# # Reading Excel file

# %%
data = pd.read_excel("/content/meap01_v4.xlsx")
data
