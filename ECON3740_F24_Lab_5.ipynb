# %% [markdown]
# <a href="https://colab.research.google.com/github/havaledar/ECON3740_F24/blob/main/ECON3740_F24_Lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Reading data from different sources

# %% [markdown]
# ## Google Drive

# %%
# !pip install gdown==v4.6.3
import gdown
import pandas as pd

# %% [markdown]
# 1.   Upload your file to the Google Drive.
# 2.   Click **Share** and change the access to **Anyone with the link**.
# 3. Copy the URL to the file.

# %% [markdown]
# ![Screenshot 2024-09-27 7.12.07 AM.png](data:image/png;base64,...)

# %%
url = 'https://drive.google.com/file/d/1PzmnjSE3-E2pSXc9bBp0_uWFTIuLsOWd/view?usp=sharing'

output_filename = 'file.dta'

gdown.download(url, output_filename, fuzzy=True ,quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1PzmnjSE3-E2pSXc9bBp0_uWFTIuLsOWd
# To: /content/file.dta
# 100%|██████████| 13.5M/13.5M [00:00<00:00, 101MB/s]
# 'file.dta'

# %%
pd.read_stata("file.dta")
# Out:
#         REC_NUM SURVYEAR SURVMNTH              LFSSTAT              PROV  \
# 0             1     2017    March    Employed, at work           Ontario
# 1             2     2017    March    Employed, at work  British Columbia
# 2             3     2017    March    Employed, at work  British Columbia
# 3             4     2017    March  Not in labour force           Ontario
# 4             5     2017    March  Not in labour force            Quebec
# ...         ...      ...      ...                  ...               ...
# 103025   103026     2017    March  Not in labour force            Quebec
# 103026   103027     2017    March    Employed, at work           Alberta
# 103027   103028     2017    March    Employed, at work     New Brunswick
# 103028   103029     2017    March  Not in labour force       Nova Scotia
# 103029   103030     2017    March  Not in labour force           Alberta
#
#                          CMA          AGE_12           AGE_6     SEX  \
# 0                   Hamilton  55 to 59 years             NaN    Male
# 1                  Vancouver  40 to 44 years             NaN  Female
# 2       Other CMA or non-CMA  15 to 19 years  17 to 19 years  Female
# 3       Other CMA or non-CMA  60 to 64 years             NaN    Male
# 4       Other CMA or non-CMA  15 to 19 years  17 to 19 years    Male
# ...                      ...             ...             ...     ...
# 103025                Québec  15 to 19 years  17 to 19 years    Male
# 103026  Other CMA or non-CMA  55 to 59 years             NaN    Male
# 103027  Other CMA or non-CMA  60 to 64 years             NaN    Male
# 103028  Other CMA or non-CMA     70 and over             NaN  Female
# 103029  Other CMA or non-CMA  15 to 19 years  15 to 16 years    Male
#
#                       MARSTAT  ... LKATADS LKANSADS LKOTHERN PRIORACT YNOLOOK  \
# 0                     Married  ...     NaN      NaN      NaN      NaN     NaN
# 1                     Married  ...     NaN      NaN      NaN      NaN     NaN
# 2       Single, never married  ...     NaN      NaN      NaN      NaN     NaN
# 3                     Widowed  ...     NaN      NaN      NaN      NaN     NaN
# 4       Single, never married  ...     NaN      NaN      NaN      NaN     NaN
# ...                       ...  ...     ...      ...      ...      ...     ...
# 103025  Single, never married  ...     NaN      NaN      NaN      NaN     NaN
# 103026                Married  ...     NaN      NaN      NaN      NaN     NaN
# 103027                Married  ...     NaN      NaN      NaN      NaN     NaN
# 103028                Widowed  ...     NaN      NaN      NaN      NaN     NaN
# 103029  Single, never married  ...     NaN      NaN      NaN      NaN     NaN
#
#        TLOLOOK            SCHOOLN  \
# 0          NaN        Non-student
# 1          NaN        Non-student
# 2          NaN        Non-student
# 3          NaN        Non-student
# 4          NaN  Full-time student
# ...        ...                ...
# 103025     NaN  Full-time student
# 103026     NaN        Non-student
# 103027     NaN        Non-student
# 103028     NaN                NaN
# 103029     NaN  Full-time student
#
#                                                  EFAMTYPE  \
# 0       Husband-wife, dual earner couple, youngest chi...
# 1       Husband-wife, single earner couple, wife emplo...
# 2       Husband-wife, dual earner couple, youngest chi...
# 3                                          Other families
# 4       Husband-wife, dual earner couple, youngest chi...
# ...                                                   ...
# 103025  Husband-wife, dual earner couple, youngest chi...
# 103026  Husband-wife, dual earner couple, no children ...
# 103027  Husband-wife, dual earner couple, no children ...
# 103028                              Unattached individual
# 103029  Single-parent family, parent employed, younges...
#
#                               AGYOWNK FINALWT
# 0       Youngest child 18 to 24 years     380
# 1       Youngest child 13 to 17 years     720
# 2                                 NaN      85
# 3                                 NaN     245
# 4                                 NaN      67
# ...                               ...     ...
# 103025                            NaN     295
# 103026                            NaN      98
# 103027                            NaN      90
# 103028                            NaN     112
# 103029                            NaN      78
#
# [103030 rows x 60 columns]

# %% [markdown]
# ## pyreadstat

# %%
# %%capture
# !pip install pyreadstat
import pyreadstat

# %%
df, meta = pyreadstat.read_dta("/content/file.dta")

# %%
meta.column_names

# %%
meta.column_labels

# %%
meta.value_labels['LFSSTAT']
# Out:
# {1: 'Employed, at work',
#  2: 'Employed, absent from work',
#  3: 'Unemployed',
#  4: 'Not in labour force'}

# %% [markdown]
# ## URL

# %%
df1 = pd.read_excel("https://cengage-dps.s3.amazonaws.com/economics/690273_wooldridge_8e/meap01_v4.xlsx")

# %%
df1.head()
# Out:
#    dcode  bcode  math4  read4  lunch  enroll   expend     exppp   lenroll  \
# 0  82160     48   68.5   57.4  17.31     364  1602988  4403.813  5.897154
# 1  50140   5223   74.0   46.8  23.63     474  2615864  5518.700  6.161207
# 2  82110   4094   87.3   56.4  30.77     403  1923443  4772.812  5.998937
# 3  82140   1888   47.3   50.9  11.90     294  1356769  4614.860  5.683580
# 4  82010    689   84.2   81.6  14.12     177   974155  5503.701  5.176150
#
#     lexpend    lexppp
# 0  14.28738  8.390226
# 1  14.77711  8.615897
# 2  14.46963  8.470691
# 3  14.12062  8.437037
# 4  13.78933  8.613176

# %% [markdown]
# ## Stats Canada

# %%
# %%capture
# !pip install stats-can

# %%
import stats_can

# %% [markdown]
# Total employed, all classes of workers
#
# https://www150.statcan.gc.ca/t1/tbl1/en/cv.action?pid=1410028801

# %%
df = stats_can.sc.vectors_to_df('v2066967', periods = 20)
# Out:
# /usr/local/lib/python3.10/dist-packages/stats_can/sc.py:656: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   .assign(refPer=lambda x: pd.to_datetime(x["refPer"], errors="ignore"))

# %%
df.columns = ['Total employed']

df
# Out:
#             Total employed
# refPer
# 2023-01-01         20017.0
# 2023-02-01         20034.9
# 2023-03-01         20076.4
# 2023-04-01         20114.5
# 2023-05-01         20115.5
# 2023-06-01         20173.0
# 2023-07-01         20168.1
# 2023-08-01         20219.1
# 2023-09-01         20269.8
# 2023-10-01         20293.7
# 2023-11-01         20318.1
# 2023-12-01         20324.9
# 2024-01-01         20362.2
# 2024-02-01         20402.9
# 2024-03-01         20400.7
# 2024-04-01         20491.1
# 2024-05-01         20517.8
# 2024-06-01         20516.4
# 2024-07-01         20513.6
# 2024-08-01         20535.7

# %% [markdown]
# ## Scraping

# %%
url = "https://en.wikipedia.org/wiki/Economy_of_Canada"

# %% [markdown]
# ### Pandas

# %%
tables = pd.read_html(url)

# %%
tables[4]
# Out:
#     Rank    Date announced                  Acquiror name Acquiror nation  \
# 0      1  January 26, 2000                       Spin-off          Canada
# 1      2     June 20, 2000                     Vivendi SA          France
# 2      3  December 7, 2007  Rio Tinto Canada Holdings Inc          Canada
# 3      4      June 9, 2016                   Enbridge Inc          Canada
# 4      5    March 12, 2014           Enbridge Income Fund          Canada
# 5      6  November 5, 2008                   Shareholders          Canada
# 6      7     July 23, 2012       CNOOC Canada Holding Ltd          Canada
# 7      8      May 15, 2006                    Xstrata PLC     Switzerland
# 8      9  November 8, 2006        Cia Vale do Rio Doce SA          Brazil
# 9     10    March 23, 2009              Suncor Energy Inc          Canada
# 10    11     July 29, 2008               Teck Cominco Ltd          Canada
#
#                     Target name  Target nation  Value (in bil. USD)
# 0          Nortel Networks Corp         Canada                59.97
# 1                Seagram Co Ltd         Canada                40.43
# 2                     Alcan Inc         Canada                37.63
# 3           Spectra Energy Corp  United States                28.29
# 4          Enbridge Inc-Liquids         Canada                24.79
# 5            Cenovus Energy Inc         Canada                20.26
# 6                     Nexen Inc         Canada                19.12
# 7              Falconbridge Ltd         Canada                17.40
# 8                      Inco Ltd         Canada                17.15
# 9                  Petro-Canada         Canada                15.58
# 10  Fording Canadian Coal Trust         Canada                13.60

# %% [markdown]
# ### BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup

# %%
# Downloading contents of the web page
data = requests.get(url).text

# %%
data
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Economy of Canada - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available";var cookie=document.cookie.match(/(?:^|; )enwikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split(\'%2C\').forEach(function(pref){className=className.replace(new RegExp(\'(^| )\'+pref.replace(/-clientpref-\\w+$|[^\\w-]+/g,\'\')+\'-clientpref-\\\\w+( |$)\'),\'$1\'+pref+\'$2\');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy",\n"wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"237ea747-a2bd-4f7a-bf1f-da25bcbcb777","wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Economy_of_Canada","wgTitle":"Economy of Canada","wgCurRevisionId":1247332728,"wgRevisionId":1247332728,"wgArticleId":5195,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Pages with non-numeric formatnum arguments","All articles with dead external links","Articles with dead external links from February 2023","Articles with permanently dead external links","Articles with dead external links from October 2022","Articles containing potentially dated statements from November 2018","All articles containing potentially dated statements","Articles with dead external links from June 2023","Source attribution","Webarchive template wayback links",\n"Articles with dead external links from December 2016","Articles with short description","Short description is different from Wikidata","Use Canadian English from September 2017","All Wikipedia articles written in Canadian English","Use mdy dates from August 2020","Articles containing potentially dated statements from 2023","All articles with unsourced statements","Articles with unsourced statements from March 2021","Articles with unsourced statements from May 2007","All articles with vague or ambiguous time","Vague or ambiguous time from March 2018","Commons category link from Wikidata","Economy of Canada","OECD member economies","World Trade Organization member economies"],"wgPageViewLanguage":"en","wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Economy_of_Canada","wgRelevantArticleId":5195,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgNoticeProject":"wikipedia",\n"wgCiteReferencePreviewsActive":false,"wgFlaggedRevsParams":{"tags":{"status":{"levels":1}}},"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":6,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true," ...

# %%
# Creating BeautifulSoup object
soup = BeautifulSoup(data, 'html.parser')

# %%
# Verifying tables and their classes
print('Classes of each table:')
for table in soup.find_all('table'):
    print(table.get('class'))
# Out:
# Classes of each table:
# ['infobox']
# ['sidebar', 'sidebar-collapse', 'nomobile', 'nowraplinks', 'hlist']
# ['wikitable']
# ['wikitable', 'sortable']
# ['wikitable']
# ['wikitable', 'mw-collapsible', 'mw-collapsed']
# ['sortable', 'wikitable']
# ['sortable', 'wikitable']
# ['sortable', 'wikitable']
# ['nowraplinks', 'mw-collapsible', 'autocollapse', 'navbox-inner']
# ['nowraplinks', 'mw-collapsible', 'mw-collapsed', 'navbox-inner']
# ['nowraplinks', 'hlist', 'mw-collapsible', 'autocollapse', 'navbox-inner']
# ['nowraplinks', 'mw-collapsible', 'autocollapse', 'navbox-inner']
# ['nowraplinks', 'hlist', 'mw-collapsible', 'mw-collapsed', 'navbox-inner']
# ['nowraplinks', 'navbox-subgroup']
# ['nowraplinks', 'mw-collapsible', 'autocollapse', 'navbox-inner']
# ['nowraplinks', 'mw-collapsible', 'autocollapse', 'navbox-inner']
# ['nowraplinks', 'hlist', 'mw-collapsible', 'autocollapse', 'navbox-inner']
# ['nowraplinks', 'mw-collapsible', 'mw-collapsed', 'navbox-inner']
# ['nowraplinks', 'hlist', 'navbox-inner']

# %%
# Creating list with all tables
tables = soup.find_all('table')

# %%
tables[5]

# %%
columns = [
    'Year',
    'GDP_PPP_Bil_USD',
    'GDP_per_capita_PPP_USD',
    'GDP_nominal_Bil_USD',
    'GDP_per_capita_nominal_USD',
    'GDP_growth_real',
    'Inflation_rate_percent',
    'Unemployment_percent',
    'Government_debt_percent_of_GDP'
]

df = pd.DataFrame(columns=columns)

# %%
for row in tables[5].tbody.find_all('tr'):
    # Find all data for each column
    columns = row.find_all('td')

    if columns != []:
        year = columns[0].text.strip()
        gdp_ppp_bil_usd = columns[1].text.strip()
        gdp_per_capita_ppp_usd = columns[2].text.strip()
        gdp_nominal_bil_usd = columns[3].text.strip()
        gdp_per_capita_nominal_usd = columns[4].text.strip()
        gdp_growth_real = columns[5].text.strip()
        inflation_rate_percent = columns[6].text.strip()
        unemployment_percent = columns[7].text.strip()
        government_debt_percent_of_gdp = columns[8].text.strip()

        row_data = {
            'Year': year,
            'GDP_PPP_Bil_USD': gdp_ppp_bil_usd,
            'GDP_per_capita_PPP_USD': gdp_per_capita_ppp_usd,
            'GDP_nominal_Bil_USD': gdp_nominal_bil_usd,
            'GDP_per_capita_nominal_USD': gdp_per_capita_nominal_usd,
            'GDP_growth_real': gdp_growth_real,
            'Inflation_rate_percent': inflation_rate_percent,
            'Unemployment_percent': unemployment_percent,
            'Government_debt_percent_of_GDP': government_debt_percent_of_gdp
        }

        # Convert row_data to a DataFrame
        row_df = pd.DataFrame([row_data])

        # Use pandas.concat to add the row to the df_short DataFrame
        df = pd.concat([df, row_df], ignore_index=True)

# %%
df.head()
# Out:
#    Year GDP_PPP_Bil_USD GDP_per_capita_PPP_USD GDP_nominal_Bil_USD  \
# 0  1980           288.7               11,798.2               276.1
# 1  1981           327.1               13,197.5               307.2
# 2  1982           336.2               13,404.9               314.6
# 3  1983           358.5               14,149.5               341.9
# 4  1984           393.4               15,380.2               356.7
#
#   GDP_per_capita_nominal_USD GDP_growth_real Inflation_rate_percent  \
# 0                   11,281.4            2.2%                  10.2%
# 1                   12,396.7            3.5%                  12.5%
# 2                   12,543.9           -3.2%                  10.8%
# 3                   13,493.2            2.6%                   5.8%
# 4                   13,947.4            5.9%                   4.3%
#
#   Unemployment_percent Government_debt_percent_of_GDP
# 0                 7.5%                          44.6%
# 1                 7.6%                          46.1%
# 2                11.1%                          51.7%
# 3                12.0%                          57.2%
# 4                11.4%                          60.2%
