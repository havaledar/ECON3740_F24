# %% [markdown]
# <a href="https://colab.research.google.com/github/havaledar/ECON3740_F24/blob/main/ECON3740_F24_Lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Google Colab Notebook

# %% [markdown]
# ## Creating New Notebook

# %% [markdown]
# 1.   Create a Notebook by cliking on this. https://colab.google/
# 2.   Use the Notebook shared in the GitHub and save it to your Google Drive.
# 3.   Click File > New Notebook in Drive.

# %% [markdown]
# # Reading Excel file

# %% [markdown]
# ### Donwload the Excel file

# %% [markdown]
# First download the data by clicking on the Open Excel File in MindTap.

# %% [markdown]
# ![Screenshot from 2024-09-11 17-35-10.png](data:image/png;base64,...)

# %% [markdown]
# ### Import pandas

# %%
import pandas as pd

# %% [markdown]
# ### read_excel

# %% [markdown]
# $\color{Red}{\text{Do not use the data from Wooldridge library.}}$

# %% [markdown]
# Instead, upload the Excel file to the Google Colab and read the file like this:

# %%
data = pd.read_excel("/content/meap01_v4.xlsx")
data
# Out:
#       dcode  bcode  math4  read4  lunch  enroll   expend     exppp   lenroll  \
# 0     82160     48   68.5   57.4  17.31     364  1602988  4403.813  5.897154
# 1     50140   5223   74.0   46.8  23.63     474  2615864  5518.700  6.161207
# 2     82110   4094   87.3   56.4  30.77     403  1923443  4772.812  5.998937
# 3     82140   1888   47.3   50.9  11.90     294  1356769  4614.860  5.683580
# 4     82010    689   84.2   81.6  14.12     177   974155  5503.701  5.176150
# ...     ...    ...    ...    ...    ...     ...      ...       ...       ...
# 1726  67055   5350   69.8   46.5  38.74     222  1036401  4668.473  5.402678
# 1727  47080   3037   86.7   81.7  13.06     222  1266669  5705.716  5.402678
# 1728  45040   2764   75.0   75.0  34.14     290  1831344  6314.979  5.669881
# 1729   7020   5784   50.0   57.1  34.99     483   991466  2052.725  6.180017
# 1730  82365   6420   70.4   64.8  36.34     344  2030546  5902.750  5.840641
#
#        lexpend    lexppp
# ...

# %% [markdown]
# # Reading data
#
# For the lab, I am using the library but you should only use the Excel file provided in the MindTap.

# %%
# %%capture

# !pip install wooldridge

import wooldridge as woo

data = woo.data('401k')

# %%
data
# Out:
#            prate  mrate  totpart  totelg  age  totemp  sole   ltotemp
# 0      26.100000   0.21   1653.0  6322.0    8  8709.0     0  9.072112
# 1     100.000000   1.42    262.0   262.0    6   315.0     1  5.752573
# 2      97.599998   0.91    166.0   170.0   10   275.0     1  5.616771
# 3     100.000000   0.42    257.0   257.0    7   500.0     0  6.214608
# 4      82.500000   0.53    591.0   716.0   28   933.0     1  6.838405
# ...          ...    ...      ...     ...  ...     ...   ...       ...
# 1529   85.099998   0.33    553.0   650.0   24   907.0     0  6.810143
# 1530  100.000000   2.52    142.0   142.0   17   197.0     1  5.283204
# 1531  100.000000   2.27   1928.0  1928.0   35  2171.0     0  7.682943
# 1532  100.000000   0.58    166.0   166.0    8   931.0     1  6.836259
# 1533  100.000000   0.45   2179.0  2179.0   24  3187.0     0  8.066835
#
# [1534 rows x 8 columns]

# %% [markdown]
# # Regression

# %%
import statsmodels.formula.api as smf

# Create the model
model = smf.ols('totpart ~ totelg', data)

# Fit the model
results = model.fit()

# Display regression results
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                totpart   R-squared:                       0.953
# Model:                            OLS   Adj. R-squared:                  0.953
# Method:                 Least Squares   F-statistic:                 3.091e+04
# Date:                Fri, 13 Sep 2024   Prob (F-statistic):               0.00
# Time:                        11:00:30   Log-Likelihood:                -12782.
# No. Observations:                1534   AIC:                         2.557e+04
# Df Residuals:                    1532   BIC:                         2.558e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -15.9342     26.848     -0.593      0.553     -68.597      36.729
# ...

# %% [markdown]
# # Reading Stata Files

# %% [markdown]
# ## read_stata

# %% [markdown]
# Once the file is uploaded and the libraries you are going to use imported, you can read it into a DataFrame.
#
# ```python
# data = pd.read_stata('file.dta')
# ```
#
# Make sure the filename matches the uploaded file.
#
# You can also reference the full Google Colab filesystem path if needed:
#
# ```
# data = pd.read_stata('/content/file.dta')
# ```
#
# For example, we can import a dta file of survey data downloaded from a website:
#
# To read a dta file into a DataFrame:
#
# ```python
# data = pd.read_stata('LFS-71M0001-E-2023-August_F1.dta')
# ```
#
# Pandas will automatically convert the data into a DataFrame.
#
# Here is the documentation for read_stata.
# https://colab.research.google.com/corgiredirector?site=https%3A%2F%2Fpandas.pydata.org%2Fdocs%2Freference%2Fapi%2Fpandas.read_stata.html

# %% [markdown]
# ## Labels or Values
#
# When you are reading the dta files, you can indicate if you need the values(convert_categoricals = False) or the lables(convert_categoricals = True) for the categorical variables as below. The read_stata by default read the lables not the values.
#
# ```python
# data = pd.read_stata('LFS-71M0001-E-2023-August_F1.dta', convert_categoricals=False)
# ```

# %%
data_stata_labels = pd.read_stata("/content/LFS-71M0001-E-2023-January_F1.dta")
data_stata_labels
# Out:
#         REC_NUM  SURVYEAR SURVMNTH                     LFSSTAT  \
# 0             1      2023  January           Employed, at work
# 1             2      2023  January           Employed, at work
# 2             3      2023  January           Employed, at work
# 3             4      2023  January         Not in labour force
# 4             5      2023  January           Employed, at work
# ...         ...       ...      ...                         ...
# 108059   108060      2023  January  Employed, absent from work
# 108060   108061      2023  January         Not in labour force
# 108061   108062      2023  January           Employed, at work
# 108062   108063      2023  January         Not in labour force
# 108063   108064      2023  January         Not in labour force
#
#                              PROV                   CMA          AGE_12  \
# 0                          Quebec              Montréal  45 to 49 years
# ...

# %%
data_stata_values = pd.read_stata('/content/LFS-71M0001-E-2023-January_F1.dta', convert_categoricals=False)
data_stata_values
# Out:
#         REC_NUM  SURVYEAR  SURVMNTH  LFSSTAT  PROV  CMA  AGE_12  AGE_6  SEX  \
# 0             1      2023         1        1    24    2       7    NaN    2
# 1             2      2023         1        1    47    0       4    NaN    2
# 2             3      2023         1        1    10    0      10    NaN    1
# 3             4      2023         1        4    35    0      12    NaN    2
# 4             5      2023         1        1    35    0       5    NaN    1
# ...         ...       ...       ...      ...   ...  ...     ...    ...  ...
# 108059   108060      2023         1        2    46    6       8    NaN    2
# 108060   108061      2023         1        4    11    0      12    NaN    2
# 108061   108062      2023         1        1    24    0       8    NaN    1
# 108062   108063      2023         1        4    35    4      12    NaN    2
# 108063   108064      2023         1        4    59    9       2    3.0    2
#
# ...

# %% [markdown]
# ## Description

# %%
data_stata = pd.read_stata('/content/LFS-71M0001-E-2023-January_F1.dta', iterator=True)
data_stata.variable_labels()
# Out:
# {'REC_NUM': 'Order of record in file',
#  'SURVYEAR': 'Survey year',
#  'SURVMNTH': 'Survey month',
#  'LFSSTAT': 'Labour force status',
#  'PROV': 'Province',
#  'CMA': 'Nine largest CMAs',
#  'AGE_12': 'Five-year age group of respondent',
#  'AGE_6': 'Age in 2 and 3 year groups, 15 to 29',
#  'SEX': 'Sex of respondent',
#  'MARSTAT': 'Marital status of respondent',
#  'EDUC': 'Highest educational attainment',
#  'MJH': 'Single or multiple jobholder',
#  'EVERWORK': 'Not currently employed, worked in the past',
#  'FTPTLAST': 'Full- or part-time status of last job',
#  'COWMAIN': 'Class of worker, main job',
#  'IMMIG': 'Immigration status',
#  'NAICS_21': 'Industry of main job',
#  'NOC_10': 'Occupation at main job',
#  'NOC_43': 'Occupation at main job',
#  'YABSENT': 'Reason of absence, full week',
#  'WKSAWAY': 'Number of weeks absent from work',
#  'PAYAWAY': 'Paid for time off, full-week absence only',
#  'UHRSMAIN': 'Usual hours worked per week at main job',
# ...

# %% [markdown]
# ## Type

# %%
data_stata_type = pd.read_stata('/content/LFS-71M0001-E-2023-January_F1.dta', preserve_dtypes=True)
data_stata_type.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108064 entries, 0 to 108063
# Data columns (total 60 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   REC_NUM   108064 non-null  int32
#  1   SURVYEAR  108064 non-null  int16
#  2   SURVMNTH  108064 non-null  category
#  3   LFSSTAT   108064 non-null  category
#  4   PROV      108064 non-null  category
#  5   CMA       108064 non-null  category
#  6   AGE_12    108064 non-null  category
#  7   AGE_6     20502 non-null   category
#  8   SEX       108064 non-null  category
#  9   MARSTAT   108064 non-null  category
#  10  EDUC      108064 non-null  category
#  11  MJH       63081 non-null   category
#  12  EVERWORK  44983 non-null   category
#  13  FTPTLAST  7621 non-null    category
#  14  COWMAIN   70702 non-null   category
#  15  IMMIG     108064 non-null  category
#  16  NAICS_21  70702 non-null   category
#  17  NOC_10    70702 non-null   category
# ...

# %% [markdown]
# # Pandas

# %% [markdown]
# ## shape

# %%
data_stata_labels.shape
# Out:
# (108064, 60)

# %% [markdown]
# ## head

# %%
data_stata_labels.head()
# Out:
#    REC_NUM  SURVYEAR SURVMNTH              LFSSTAT                       PROV  \
# 0        1      2023  January    Employed, at work                     Quebec
# 1        2      2023  January    Employed, at work               Saskatchewan
# 2        3      2023  January    Employed, at work  Newfoundland and Labrador
# 3        4      2023  January  Not in labour force                    Ontario
# 4        5      2023  January    Employed, at work                    Ontario
#
#                     CMA          AGE_12 AGE_6     SEX                MARSTAT  \
# 0              Montréal  45 to 49 years   NaN  Female  Single, never married
# 1  Other CMA or non-CMA  30 to 34 years   NaN  Female  Single, never married
# 2  Other CMA or non-CMA  60 to 64 years   NaN    Male                Married
# 3  Other CMA or non-CMA     70 and over   NaN  Female                Married
# 4  Other CMA or non-CMA  35 to 39 years   NaN    Male                Married
#
# ...

# %% [markdown]
# ## tail

# %%
data_stata_labels.tail()
# Out:
#         REC_NUM  SURVYEAR SURVMNTH                     LFSSTAT  \
# 108059   108060      2023  January  Employed, absent from work
# 108060   108061      2023  January         Not in labour force
# 108061   108062      2023  January           Employed, at work
# 108062   108063      2023  January         Not in labour force
# 108063   108064      2023  January         Not in labour force
#
#                         PROV                   CMA          AGE_12  \
# 108059              Manitoba              Winnipeg  50 to 54 years
# 108060  Prince Edward Island  Other CMA or non-CMA     70 and over
# 108061                Quebec  Other CMA or non-CMA  50 to 54 years
# 108062               Ontario               Toronto     70 and over
# 108063      British Columbia             Vancouver  20 to 24 years
#
#                  AGE_6     SEX                MARSTAT  ... LKATADS LKANSADS  \
# 108059             NaN  Female              Separated  ...     NaN      NaN
# ...

# %% [markdown]
# ## drop

# %%
data_drop = data_stata_labels.drop(columns=['SURVYEAR'])
data_drop
# Out:
#         REC_NUM SURVMNTH                     LFSSTAT  \
# 0             1  January           Employed, at work
# 1             2  January           Employed, at work
# 2             3  January           Employed, at work
# 3             4  January         Not in labour force
# 4             5  January           Employed, at work
# ...         ...      ...                         ...
# 108059   108060  January  Employed, absent from work
# 108060   108061  January         Not in labour force
# 108061   108062  January           Employed, at work
# 108062   108063  January         Not in labour force
# 108063   108064  January         Not in labour force
#
#                              PROV                   CMA          AGE_12  \
# 0                          Quebec              Montréal  45 to 49 years
# 1                    Saskatchewan  Other CMA or non-CMA  30 to 34 years
# 2       Newfoundland and Labrador  Other CMA or non-CMA  60 to 64 years
# ...

# %% [markdown]
# ## new column

# %%
data_stata_labels['Year'] = data_stata_labels['SURVYEAR']+1
data_stata_labels

#lab3valuecount
# Out:
#         REC_NUM  SURVYEAR SURVMNTH                     LFSSTAT  \
# 0             1      2023  January           Employed, at work
# 1             2      2023  January           Employed, at work
# 2             3      2023  January           Employed, at work
# 3             4      2023  January         Not in labour force
# 4             5      2023  January           Employed, at work
# ...         ...       ...      ...                         ...
# 108059   108060      2023  January  Employed, absent from work
# 108060   108061      2023  January         Not in labour force
# 108061   108062      2023  January           Employed, at work
# 108062   108063      2023  January         Not in labour force
# 108063   108064      2023  January         Not in labour force
#
#                              PROV                   CMA          AGE_12  \
# 0                          Quebec              Montréal  45 to 49 years
# ...
